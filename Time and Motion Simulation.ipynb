# %%
from main import *
from plot_data import *

# %% [markdown]
# # Scenario 1 2 8
#
# * Simulate 199 staff going to floors 9-13 and 232 staff going to floors 2-8. It can be more-or-less an even breakdown between the floors.
# * 2 Employee after the gate
# * 8 Functioning elevators

# %%
from scenario1 import *

# %%
main(config)
# Out:
# Starting 1000 Runs, 8 elevators
# Run #001 Allocating 402 employees over 10800 seconds
# Run #002 Allocating 402 employees over 10800 seconds
# Run #003 Allocating 402 employees over 10800 seconds
# Run #004 Allocating 402 employees over 10800 seconds
# Run #005 Allocating 402 employees over 10800 seconds
# Run #006 Allocating 402 employees over 10800 seconds
# Run #007 Allocating 402 employees over 10800 seconds
# Run #008 Allocating 402 employees over 10800 seconds
# Run #009 Allocating 402 employees over 10800 seconds
# Run #010 Allocating 402 employees over 10800 seconds
# Run #011 Allocating 402 employees over 10800 seconds
# Run #012 Allocating 402 employees over 10800 seconds
# Run #013 Allocating 402 employees over 10800 seconds
# Run #014 Allocating 402 employees over 10800 seconds
# Run #015 Allocating 402 employees over 10800 seconds
# Run #016 Allocating 402 employees over 10800 seconds
# Run #017 Allocating 402 employees over 10800 seconds
# ...

# %%
plot_data(config)
# Out:
# Overall queue stats:
#                ticks         length            run           hour
# count  271226.000000  271226.000000  271226.000000  271226.000000
# mean     4471.090928       2.551997     501.162573       1.835219
# std      1708.308837       2.712183     287.917246       0.443577
# min         1.000000       0.000000       1.000000       1.000000
# 25%      3815.000000       1.000000     253.000000       2.000000
# 50%      4524.000000       2.000000     501.000000       2.000000
# 75%      5440.000000       3.000000     750.000000       2.000000
# max     10833.000000      27.000000    1000.000000       4.000000
# First hour:
#               ticks        length           run     hour
# count  52695.000000  52695.000000  52695.000000  52695.0
# mean    1883.304033      1.137394    502.834273      1.0
# std      986.556531      1.099979    289.106383      0.0
# min        1.000000      0.000000      1.000000      1.0
# ...
